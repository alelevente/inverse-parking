# %% [markdown]
# # **Result visualization**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
RESULTS_ROOT = "../01_simulation/04_results/"
SEEDS = ['42', '1234', '1867', '613', '1001']

# %%
p_data = pd.DataFrame()
#READING DATA:
for s in SEEDS:
    filename = RESULTS_ROOT+f'poccup_by_vehs_{s}.csv'
    pf = pd.read_csv(filename)
    pf["seed"] = [s]*len(pf)
    p_data = pd.concat([p_data, pf])
    
p_data["time"] = p_data["time"] - 4*24*60*60
p_data["time"] = p_data["time"].astype(int)
p_data["time_of_day"] = (p_data["time"] - (p_data["time"] // (24*60*60))*24*60*60) / (24*60*60) #converting to 0.0-1.0 and removing periodicity

# %%
p_data
# Out:
#             veh_id   parking_id    time  occupancy  seed  time_of_day
# 0        h3098c1:0        pa-27      10   0.923077    42     0.000116
# 1        h3098c1:0        pa-71      10   0.842105    42     0.000116
# 2        h3098c1:0         pa27      10   0.769231    42     0.000116
# 3        h3098c1:0        pa-27      11   0.923077    42     0.000127
# 4        h3098c1:0        pa-71      11   0.842105    42     0.000127
# ...            ...          ...     ...        ...   ...          ...
# 3128768   h798c1:0  pa-outside2  432000   0.000000  1001     0.000000
# 3128769   h798c1:0         pa11  432000   0.750000  1001     0.000000
# 3128770  h3101c1:0        pa-11  432000   0.428571  1001     0.000000
# 3128771  h3101c1:0  pa-outside2  432000   0.000000  1001     0.000000
# 3128772  h3101c1:0         pa11  432000   0.750000  1001     0.000000
#
# [15678789 rows x 6 columns]

# %%
parkings = p_data["parking_id"].unique()

# %% [markdown]
# ## Values by parking lots

# %%
p_data_by_parking = {}
for p in parkings:
    p_filt = p_data[p_data["parking_id"] == p]
    p_filt = p_filt.groupby("time_of_day")["occupancy"].mean()
    p_data_by_parking[p] = p_filt

# %%
for p in parkings:
    plt.plot(p_data_by_parking[p].index*24, p_data_by_parking[p].values)
    plt.title(p)
    plt.show()

# %% [markdown]
# ## Results by vehicles

# %%
p_data["veh_id"].unique()[500:600]
# Out:
# array(['carIn241:4', 'h3234c1:0', 'carIn451:4', 'h2649c1:0', 'h2557c2:0',
#        'carIn551:4', 'randUni897:4', 'carIn67:4', 'randUni312:4',
#        'carIn922:4', 'carIn622:4', 'h3369c1:0', 'h3406c2:0', 'carIn383:4',
#        'h22c1:0', 'randUni65:4', 'h3484c1:0', 'h3390c1:0', 'randUni349:4',
#        'h2544c1:0', 'h3319c1:0', 'carIn22:4', 'h482c1:0', 'h3120c1:0',
#        'h2453c1:0', 'carIn330:4', 'carIn786:4', 'randUni651:4',
#        'randUni996:4', 'h2115c1:0', 'h3401c2:0', 'carIn92:4',
#        'carIn901:4', 'h2253c1:0', 'carIn581:4', 'carIn46:4', 'carIn294:4',
#        'carIn72:4', 'carIn141:4', 'carIn95:4', 'carIn127:4', 'h3405c2:0',
#        'carIn346:4', 'h3429c1:0', 'h3408c1:0', 'carIn90:4', 'carIn423:4',
#        'h3293c1:0', 'carIn175:4', 'carIn56:4', 'carIn708:4', 'carIn25:4',
#        'h3159c1:0', 'randUni476:4', 'randUni364:4', 'carIn337:4',
#        'h3088c1:0', 'carIn106:4', 'h3425c1:0', 'h143c1:0', 'carIn758:4',
#        'carIn60:4', 'carIn641:4', 'carIn687:4', 'h3323c1:0', 'carIn409:4',
#        'h3239c1:0', 'randUni44:4', 'carIn656:4', 'h2459c1:0', 'carIn68:4',
#        'carIn740:4', 'h3101c1:0', 'carIn388:4', 'h2564c1:0', 'carIn640:4',
#        'h3304c1:0', 'carIn126:4', 'carIn573:4', 'h3271c2:0',
#        'randUni422:4', 'carIn246:4', 'h3362c1:0', 'carIn982:4',
#        'h3384c1:0', 'h3139c1:0', 'carIn571:4', 'carIn204:4', 'h864c1:0',
#        'h2657c1:0', 'randUni377:4', 'h1264c1:0', 'carIn517:4',
#        'carIn433:4', 'carIn892:4', 'carIn299:4', 'randUni188:4',
#        'h3286c2:0', 'h2901c1:0', 'h73c1:0'], dtype=object)

# %%
#VEH_ID = "h3408c1:0"
VEH_ID = "h482c1:0"
#VEH_ID = "h3120c1:0"
#VEH_ID = "h3271c2:0"
#VEH_ID = "carIn901:4"
#VEH_ID = "carIn106:4"

# %%
p_vehs = p_data[p_data["veh_id"] == VEH_ID]

# %%
p_vehs
# Out:
#          veh_id parking_id   time  occupancy  seed  time_of_day
# 68150  h482c1:0      pa-60  27265   0.346154    42     0.315567
# 68151  h482c1:0       pa60  27265   0.461538    42     0.315567
# 68155  h482c1:0      pa-60  27266   0.346154    42     0.315579
# 68156  h482c1:0       pa60  27266   0.461538    42     0.315579
# 68158  h482c1:0      pa-60  27267   0.346154    42     0.315590
# ...         ...        ...    ...        ...   ...          ...
# 58863  h482c1:0      pa-75  25577   0.236842  1001     0.296030
# 58864  h482c1:0       pa60  25577   0.423077  1001     0.296030
# 58865  h482c1:0       pa75  25577   0.210526  1001     0.296030
# 58873  h482c1:0      pa-60  25578   0.230769  1001     0.296042
# 58874  h482c1:0       pa60  25578   0.423077  1001     0.296042
#
# [1912 rows x 6 columns]

# %%
p_veh_by_parking = {}
for p in p_vehs["parking_id"].unique():
    p_filt = p_vehs[p_vehs["parking_id"] == p]
    p_filt = p_filt.groupby("time_of_day")["occupancy"].mean()
    p_veh_by_parking[p] = p_filt

# %%
MIN_ALPHA = 0.1
MAX_ALPHA = 0.5
WINDOW = 300

bins = np.arange(0, 1, 1/(24*6)) #15 minutes resolution for histogram background

for p in p_veh_by_parking:
    #background:
    hist, bin_edges = np.histogram(p_veh_by_parking[p].index, bins=bins)
    color_min = min(hist)
    color_max = max(hist)
    has_legend = False
    for i in range(len(bins)-1):
        if hist[i]>0:
            label = "moving time" if not(has_legend) else ""
            has_legend = True
                
            plt.fill_between(x=[i*1/6, (i+1)*1/6], y1=0, y2=1.0,
                             alpha=(hist[i]-color_min)/(color_max-color_min)*(MAX_ALPHA-MIN_ALPHA)+MIN_ALPHA,
                             color="tab:orange",
                             label=label)
            
    #parking data:
    ma = p_data_by_parking[p].rolling(WINDOW).mean()
    std = p_data_by_parking[p].rolling(WINDOW).std()
    plt.plot(ma.index*24, ma.values, label="mean of occupancy")
    plt.fill_between(std.index*24, ma-std, ma+std, alpha=0.5, label="std of occupancy")
    #plt.plot(p_data_by_parking[p].index*24, p_data_by_parking[p].values)
    #plt.plot(p_veh_by_parking[p].index*24, p_veh_by_parking[p].values)
    plt.title(f"Occupancy of\n{p} parking lot")
    plt.xlabel("time [h]")
    plt.ylabel("occupancy")
    plt.xticks(ticks=np.arange(0, 26, 2))
    plt.legend()
    plt.show()
